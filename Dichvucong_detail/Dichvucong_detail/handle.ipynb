# %%
import pandas as pd
import numpy as np

# %%
data_raw = pd.read_csv("/Users/dinhvan/Projects/Code/crawl/scrapy/Dichvucong_detail/Dichvucong_detail/result.csv",dtype = str)
data_raw
# Out:
#                                             company_name  \
# 0                          CÔNG TY TNHH MTV DỤNG CỤ Y TẾ
# 1      CÔNG TY CỔ PHẦN NHÀ MÁY TRANG THIẾT BỊ Y TẾ US...
# 2           CÔNG TY TNHH CÔNG NGHỆ Y TẾ PERFECT VIỆT NAM
# 3      CÔNG TY CỔ PHẦN NHÀ MÁY TRANG THIẾT BỊ Y TẾ US...
# 4      CÔNG TY CỔ PHẦN NHÀ MÁY TRANG THIẾT BỊ Y TẾ US...
# ...                                                  ...
# 66067  CÔNG TY TNHH THƯƠNG MẠI VÀ DỊCH VỤ KỸ THUẬT NG...
# 66068  CÔNG TY TNHH THƯƠNG MẠI VÀ DỊCH VỤ KỸ THUẬT NG...
# 66069  CÔNG TY TNHH THƯƠNG MẠI VÀ DỊCH VỤ KỸ THUẬT NG...
# 66070  CÔNG TY TNHH THƯƠNG MẠI VÀ DỊCH VỤ KỸ THUẬT NG...
# 66071  CÔNG TY TNHH THƯƠNG MẠI VÀ DỊCH VỤ KỸ THUẬT NG...
#
#                                            product_owner  \
# 0                                  GREAT WORLD CO., LTD.
# 1      USM HEALTHCARE MEDICAL DEVICES FACTORY JOINT S...
# 2                 PERFECT MEDICAL INDUSTRY (VN) CO., LTD
# ...

# %%
data_raw = data_raw.drop_duplicates(keep='first')
data_raw
# Out:
#                                             company_name  \
# 0                          CÔNG TY TNHH MTV DỤNG CỤ Y TẾ
# 1      CÔNG TY CỔ PHẦN NHÀ MÁY TRANG THIẾT BỊ Y TẾ US...
# 2           CÔNG TY TNHH CÔNG NGHỆ Y TẾ PERFECT VIỆT NAM
# 6                                  CÔNG TY TNHH ICT VINA
# 7                                  CÔNG TY TNHH ICT VINA
# ...                                                  ...
# 65981                               CÔNG TY TNHH SUNDENT
# 65987  CÔNG TY TNHH DƯƠC PHẨM VÀ TRANG THIẾT BỊ Y TẾ ...
# 65998             CÔNG TY TNHH THƯƠNG MẠI Y TẾ VIỄN ĐÔNG
# 66005                             CÔNG TY TNHH VIMEPHARM
# 66043     CÔNG TY TNHH XUẤT NHẬP KHẨU VÀ THƯƠNG MẠI CAHU
#
#                                            product_owner  \
# 0                                  GREAT WORLD CO., LTD.
# 1      USM HEALTHCARE MEDICAL DEVICES FACTORY JOINT S...
# 2                 PERFECT MEDICAL INDUSTRY (VN) CO., LTD
# ...
